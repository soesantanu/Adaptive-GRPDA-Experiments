# %%
import numpy as np
import scipy.linalg as LA
import scipy.sparse as spr
import scipy.sparse.linalg as spr_LA
from time import time
from time import perf_counter
from sklearn import datasets

# %%
# This part of the code is taken from the github of Yura malitsky (graal)
filename = "/content/mushrooms.txt"
#filename = "data/real-sim.bz2"
#filename = "data/rcv1_train.binary.bz2"
#filename = "data/kdda.t.bz2"

A, b =  datasets.load_svmlight_file(filename)
m, n = A.shape

print("The dataset {}. The dimensions: m={}, n={}".format(filename[5:], m, n))
# Out:
# The dataset ent/mushrooms.txt. The dimensions: m=8124, n=112

# %%
# define all ingredients for sparse logistic regression
gamma = 0.005 * LA.norm(A.T.dot(b), np.inf)
K = (A.T.multiply(-b)).T.tocsr()

# find the norm of K^T K
L = spr_LA.svds(K, k=1, return_singular_vectors=False)**2

# starting point
x0 = np.zeros(n)


g = lambda x: gamma*LA.norm(x,1)
prox_g = lambda x, rho: x + np.clip(-x, -rho*gamma, rho*gamma)


f = lambda x: np.log(1. + np.exp(x)).sum()

def df(x):
    exp_x = np.exp(x)
    return exp_x/(1.+exp_x)

dh = lambda x, Kx: K.T.dot(df(Kx))

# residual
res = lambda x: LA.norm(x-prox_g(x-dh(x,K.dot(x)), 1))

# energy
J = lambda x, Kx: f(Kx)+g(x)

# prox of g conjugate
def prox_g_conj(v: np.ndarray, gamma: float, sigma: float) -> np.ndarray:
    return np.clip(v, -gamma, gamma)

# %%
import scipy.sparse.linalg as spla

# largest singular value  ||Q||_2  (k=1 returns the top singular value)
s_max = spla.svds(K, k=1, return_singular_vectors=False)[0]
L1 = spr_LA.svds(K, k=1, return_singular_vectors=False)**2

L = s_max**2
print("Global Lipschitz constant L =", L1)
print("Local Lipschitz constant L =", L)
# Out:
# Global Lipschitz constant L = [229500.33897649]
# Local Lipschitz constant L = 229500.33897649057

# %%
# The adaptive GRPDA Algorithm

def pd_adaptive_Golden(J, prox_g_conj, K, x0, y0, tau, theta, beta, gamma, tau_max, rho_val, phi, numb_iter=100):
    begin = time()

    x, y, z = x0, y0, x0
    Kx0 = K.dot(x0)
    values = [J(x0, Kx0)]
    tau_prev = tau
    theta_prev = theta
    tt = [0]
    tau_values = []
    sigma_values = []

    for i in range(numb_iter):

        z = x - (1 / phi) * (x - z)
        x1 = z - tau_prev * y - tau_prev * dh(x, K.dot(x))
        Kx1 = K.dot(x1)
        Kx = K.dot(x)
        dhx = dh(x, Kx)
        dhx1 = dh(x1, Kx1)
        x_norm = LA.norm(x - x1)
        dhx_norm = LA.norm(dhx-dhx1)
        if dhx_norm != 0:
            L_bar_prev = (dhx_norm / x_norm) ** 2
            L_current1 = (phi * theta_prev ) / (9*tau_prev)
            L_n = L_current1 /((L_bar_prev + phi * beta))
            tau_n = min(rho_val * tau_prev, L_n, tau_max)
        else:
            tau_n = min(rho_val * tau_prev, tau_max)

        sigma_n = beta * tau_n
        y1 = prox_g_conj(y + sigma_n * x1, gamma, sigma_n)
        print(f"Iteration {i}: J_gap = {J(x1, K.dot(x1))}, tau_n = {tau_n}, x_norm = {LA.norm(x-x1)}, dhx_norm = {dhx_norm}")
        theta_n = phi * (tau_n / tau_prev)
        tau_prev = tau_n
        theta_prev = theta_n
        values.append(J(x1, K.dot(x1)))
        x, y = x1, y1
        tau_values.append(tau_n)  # Store tau_n value
        sigma_values.append(sigma_n)  # Store sigma_n value
        tt.append(time() - begin)
        err = values[-1]
        end = time()
        if err <= 1e-16:
            print ("Iter:", i+1)
            print ("----- Adaptive Golden-Ratio PDA -----")
            print ("Time execution:", round(end - begin,2))
            break
    if err > 1e-16:
      print ("Adaptive Golden-Ratio PDA does not terminate after", round(end - begin,2), "seconds")
    return [values, x, y, tt, sigma_values, tau_values]

# %%
def pd_Golden_Partial_adaptive(J, prox_g_conj, K, x0, y0,
                               mu, mu1, gamma, beta, phi, tau,
                               numb_iter=100, tol=1e-16):
    begin        = time()
    x, y, z      = x0.copy(), y0.copy(), x0.copy()
    values       = [J(x0, K.dot(x0))]
    tt           = [0.0]
    tau_prev     = tau
    tau_values   = []
    sigma_values = []

    for i in range(numb_iter):
        # 1) Extrapolation
        z = x - (1/phi)*(x - z)

        # 2) Compute gradient‑like dh at x and x1
        Kx   = K.dot(x)
        x1   = z - tau_prev*y - tau_prev*dh(x, Kx)
        Kx1  = K.dot(x1)
        dhx  = dh(x,  Kx)
        dhx1 = dh(x1, Kx1)

        # 3) Compute norms
        x_norm   = LA.norm(x - x1)
        dhx_norm = LA.norm(dhx - dhx1)

        # 4) Adaptive τₙ
        if dhx_norm !=0:
            tau_n = min(tau_prev,
                        mu/np.sqrt(beta),
                        mu1*(x_norm/dhx_norm))
        else:
            tau_n = min(tau_prev, mu/np.sqrt(beta))
        sigma_n = beta * tau_n

        # 5) Record step sizes
        tau_values.append(tau_n)
        sigma_values.append(sigma_n)

        # 6) Dual update
        y1 = prox_g_conj(y + sigma_n*x1, gamma, sigma_n)

        # 7) Record objective + time
        values.append(J(x1, K.dot(x1)))
        tt.append(time() - begin)
        print(f"Iteration {i}: J_gap = {J(x1, K.dot(x1))}, tau_n = {tau_n}, x_norm = {LA.norm(x-x1)}, Kx_norm = {dhx_norm}")
        # 8) Check convergence
        if values[-1] <= tol:
            print(f"[P‑GRPDA] Converged at iter {i+1}, time {tt[-1]:.3f}s")
            x, y = x1, y1
            break

        # 9) Prepare next iterates
        x, y, tau_prev = x1, y1, tau_n

    else:
        print(f"[P‑GRPDA] Did not converge in {numb_iter} iters (last τ={tau_n:.3e})")

    return [values, x, y, tt, sigma_values, tau_values]

# %%
def pd_Golden(J, prox_g_conj, K,  x0, y0, sigma, tau, gamma, phi, numb_iter=100):

    begin = time()

    x, y, z = x0, y0, x0
    values = [J(x0,K.dot(x0))]
    tau_values = []
    sigma_values = []
    tt = [0]

    for i in range(numb_iter):
        z = x-(1/phi)*(x - z)
        Kx = K.dot(x)
        x = z - tau * y - tau * dh(x, Kx)

        y = prox_g_conj(y + sigma * x, gamma, sigma)

        values.append(J(x, K.dot(x)))
        tau_values.append(tau)
        sigma_values.append(sigma)
        print(f"Iteration {i}: J_gap = {J(x, K.dot(x))}, tau = {tau}, phi = {phi}")
        tt.append(time() - begin)
        err = values[-1]
        end = time()
        if err <= 1e-16:
            print ("Iter:", i+1)
            print ("----- Golden-Ratio Primal-dual method -----")
            print ("Time execution:", round(end - begin,2))
            break
    if err > 1e-16:
      print ("Golden-Ratio Primal-dual method does not terminate after", round(end - begin,2), "seconds")
    return [values, x, y,tt, sigma_values, tau_values]

# %%
def pd(J, prox_g_conj, K,  x0, y0, sigma, tau, gamma, numb_iter=100):
    begin = time()
    theta = 1.0
    x, y, z = x0, y0, x0
    values = [J(x0, K.dot(x0))]
    sigma_values = []
    tau_values = []
    tt = [0]

    for i in range(numb_iter):
        Kx = K.dot(x)
        x1 = x - tau * y- tau * dh(x, Kx)
        z = x1 + theta * (x1 - x)
        y = prox_g_conj(y + sigma * z, gamma, sigma)
        print(f"Iteration {i}: J_gap = {J(x, K.dot(x))}, tau = {tau}, sigma = {sigma}, theta = {theta}")
        x = x1
        values.append(J(x, K.dot(x)))
        sigma_values.append(sigma)
        tau_values.append(tau)

        tt.append(time() - begin)
        err = values[-1]
        end = time()
        if err <= 1e-16:
            print ("Iter:", i+1)
            print ("----- Primal-dual method -----")
            print ("Time execution:", round(end - begin,2))
            break
    if err > 1e-16:
      print ("Primal-dual method does not terminate after", round(end - begin,2), "seconds")

    return [values, x, y,tt, tau_values, sigma_values]

# %%
N = 15000
tau = 1e-04
tau_agraal = 1e-5
tau_pgrpda = 7.197e-03
beta_pgrpda = 1.931e+04
x0 = np.zeros(n)
y0 = x0 + np.random.randn(x0.shape[0]) * 1e-9
theta = 1
beta = 3.154e03
tau_max = 100000000
phi = 1.5
rho_val = 1/phi + (1/phi**2)
phi_pgrpda = 1.7
mu = 0.79
mu1 = 0.26
tau_egrpda = 3.15e-06
sigma_egrpda = 3.59e+03
phi_egrpda = (1 + np.sqrt(5))/2
sigma_pd = 2e3
tau_pd = 4.15e-05
# Run all the algorithms
ans4 = pd_adaptive_Golden(J, prox_g_conj, K, x0, y0, tau, theta, beta, gamma, tau_max, rho_val, phi, numb_iter=N)
ans1 = pd_Golden(J, prox_g_conj, K,  x0, y0, sigma_egrpda, tau_egrpda, gamma, phi_egrpda, numb_iter=N)
ans5 = pd_Golden_Partial_adaptive(J, prox_g_conj, K, x0, y0, mu, mu1, gamma, beta_pgrpda, phi_pgrpda, tau_pgrpda, numb_iter=N)
ans2 = pd(J, prox_g_conj, K,  x0, y0, sigma_pd, tau_pd, gamma, numb_iter=N)
# Out:
# Streaming output truncated to the last 5000 lines.
# Iteration 10001: J_gap = 320.8675420947863, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10002: J_gap = 320.8672635453902, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10003: J_gap = 320.8669850224792, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10004: J_gap = 320.8667065260492, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10005: J_gap = 320.86642805609625, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10006: J_gap = 320.8661496126161, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10007: J_gap = 320.8658711956049, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10008: J_gap = 320.8655928050583, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10009: J_gap = 320.8653144409727, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10010: J_gap = 320.86503610334364, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10011: J_gap = 320.8647577921673, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10012: J_gap = 320.8644795074396, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10013: J_gap = 320.8642012491565, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10014: J_gap = 320.8639230173139, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10015: J_gap = 320.8636448119076, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10016: J_gap = 320.86336663293395, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10017: J_gap = 320.8630884803887, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10018: J_gap = 320.8628103542676, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10019: J_gap = 320.862532254567, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10020: J_gap = 320.86225418128254, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10021: J_gap = 320.8619761344103, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10022: J_gap = 320.8616981139464, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10023: J_gap = 320.8614201198865, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10024: J_gap = 320.86114215222676, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10025: J_gap = 320.8608642109631, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10026: J_gap = 320.86058629609147, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10027: J_gap = 320.86030840760793, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10028: J_gap = 320.8600305455084, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10029: J_gap = 320.85975270978855, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10030: J_gap = 320.85947490044487, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10031: J_gap = 320.85919711747295, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10032: J_gap = 320.85891936086904, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10033: J_gap = 320.85864163062877, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10034: J_gap = 320.85836392674844, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10035: J_gap = 320.8580862492238, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10036: J_gap = 320.8578085980509, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10037: J_gap = 320.85753097322566, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10038: J_gap = 320.8572533747443, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10039: J_gap = 320.85697580260245, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10040: J_gap = 320.85669825679634, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10041: J_gap = 320.85642073732174, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10042: J_gap = 320.8561432441748, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 
tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10218: J_gap = 320.8077108479174, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10219: J_gap = 320.8074379522066, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10220: J_gap = 320.8071650821211, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10221: J_gap = 320.806892237657, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10222: J_gap = 320.8066194188104, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10223: J_gap = 320.80634662557753, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10224: J_gap = 320.80607385795435, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10225: J_gap = 320.80580111593713, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10226: J_gap = 320.80552839952196, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10227: J_gap = 320.805255708705, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10228: J_gap = 320.80498304348225, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10229: J_gap = 320.8047104038501, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10230: J_gap = 320.80443778980435, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10231: J_gap = 320.80416520134145, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10232: J_gap = 320.80389263845734, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10233: J_gap = 320.8036201011483, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10234: J_gap = 320.8033475894104, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10235: J_gap = 320.80307510323973, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10236: J_gap = 320.80280264263234, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10237: J_gap = 320.80253020758465, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10238: J_gap = 320.80225779809274, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10239: J_gap = 320.8019854141525, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10240: J_gap = 320.8017130557604, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10241: J_gap = 320.8014407229124, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10242: J_gap = 320.80116841560465, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10243: J_gap = 320.8008961338333, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10244: J_gap = 320.8006238775946, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10245: J_gap = 320.80035164688445, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10246: J_gap = 320.8000794416993, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10247: J_gap = 320.7998072620352, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10248: J_gap = 320.7995351078882, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10249: J_gap = 320.7992629792545, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10250: J_gap = 320.7989908761303, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10251: J_gap = 320.7987187985117, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10252: J_gap = 320.79844674639486, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10253: J_gap = 320.79817471977606, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10254: J_gap = 320.7979027186512, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10255: J_gap = 320.7976307430168, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10256: J_gap = 320.7973587928685, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10257: J_gap = 320.797086868203, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10258: J_gap = 320.796814969016, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10259: J_gap = 320.79654309530406, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10260: J_gap = 320.7962712470631, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10261: J_gap = 320.7959994242893, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10262: J_gap = 320.7957276269789, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10263: J_gap = 320.795455855128, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10264: J_gap = 320.7951841087328, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10265: J_gap = 320.7949123877894, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10266: J_gap = 320.794640692294, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10267: J_gap = 320.7943690222429, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10268: J_gap = 320.79409737763206, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10269: J_gap = 320.79382575845773, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10270: J_gap = 320.7935541647161, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10271: J_gap = 320.7932825964033, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10272: J_gap = 320.79301105351544, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10273: J_gap = 320.792739536049, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10274: J_gap = 320.7924680439997, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10275: J_gap = 320.79219657736394, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10276: J_gap = 320.79192513613793, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10277: J_gap = 320.79165372031787, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10278: J_gap = 320.79138232989976, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10279: J_gap = 320.7911109648799, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10280: J_gap = 320.79083962525453, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10281: J_gap = 320.7905683110196, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10282: J_gap = 320.7902970221715, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10283: J_gap = 320.79002575870635, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10284: J_gap = 320.78975452062025, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10285: J_gap = 320.78948330790956, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10286: J_gap = 320.78921212057026, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10287: J_gap = 320.7889409585987, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10288: J_gap = 320.78866982199094, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10289: J_gap = 320.7883987107432, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10290: J_gap = 320.78812762485165, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10291: J_gap = 320.78785656431245, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10292: J_gap = 320.78758552912194, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10293: J_gap = 320.78731451927604, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10294: J_gap = 320.7870435347713, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10295: J_gap = 320.78677257560355, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10296: J_gap = 320.7865016417692, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10297: J_gap = 320.7862307332643, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10298: J_gap = 320.7859598500852, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10299: J_gap = 320.78568899222796, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10300: J_gap = 320.7854181596888, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10301: J_gap = 320.785147352464, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10302: J_gap = 320.78487657054956, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10303: J_gap = 320.7846058139419, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 10304: J_gap = 320.7843350826371, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 
tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14930: J_gap = 319.7520923771347, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14931: J_gap = 319.75190799379385, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14932: J_gap = 319.75172362411826, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14933: J_gap = 319.7515392681063, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14934: J_gap = 319.75135492575635, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14935: J_gap = 319.75117059706685, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14936: J_gap = 319.75098628203625, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14937: J_gap = 319.7508019806628, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14938: J_gap = 319.75061769294484, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14939: J_gap = 319.7504334188809, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14940: J_gap = 319.75024915846933, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14941: J_gap = 319.7500649117083, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14942: J_gap = 319.74988067859647, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14943: J_gap = 319.7496964591321, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14944: J_gap = 319.7495122533137, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14945: J_gap = 319.7493280611394, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14946: J_gap = 319.7491438826079, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14947: J_gap = 319.74895971771724, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14948: J_gap = 319.7487755664661, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14949: J_gap = 319.7485914288528, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14950: J_gap = 319.7484073048756, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14951: J_gap = 319.748223194533, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14952: J_gap = 319.74803909782327, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14953: J_gap = 319.74785501474486, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14954: J_gap = 319.74767094529625, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14955: J_gap = 319.7474868894757, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14956: J_gap = 319.7473028472817, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14957: J_gap = 319.7471188187126, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14958: J_gap = 319.74693480376664, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14959: J_gap = 319.7467508024425, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14960: J_gap = 319.74656681473823, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14961: J_gap = 319.7463828406525, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14962: J_gap = 319.74619888018356, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14963: J_gap = 319.7460149333297, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14964: J_gap = 319.7458310000897, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14965: J_gap = 319.74564708046154, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14966: J_gap = 319.7454631744438, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14967: J_gap = 319.74527928203474, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14968: J_gap = 319.74509540323294, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14969: J_gap = 319.74491153803666, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14970: J_gap = 319.74472768644426, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14971: J_gap = 319.7445438484542, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14972: J_gap = 319.7443600240649, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14973: J_gap = 319.7441762132748, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14974: J_gap = 319.74399241608205, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14975: J_gap = 319.74380863248524, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14976: J_gap = 319.74362486248276, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14977: J_gap = 319.74344110607296, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14978: J_gap = 319.74325736325426, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14979: J_gap = 319.74307363402494, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14980: J_gap = 319.74288991838347, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14981: J_gap = 319.7427062163283, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14982: J_gap = 319.7425225278577, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14983: J_gap = 319.7423388529702, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14984: J_gap = 319.7421551916642, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14985: J_gap = 319.74197154393806, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14986: J_gap = 319.74178790979, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14987: J_gap = 319.74160428921857, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14988: J_gap = 319.74142068222227, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14989: J_gap = 319.7412370887992, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14990: J_gap = 319.7410535089482, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14991: J_gap = 319.74086994266725, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14992: J_gap = 319.7406863899549, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14993: J_gap = 319.74050285080955, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14994: J_gap = 319.74031932522956, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14995: J_gap = 319.7401358132134, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14996: J_gap = 319.7399523147594, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14997: J_gap = 319.739768829866, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14998: J_gap = 319.73958535853166, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Iteration 14999: J_gap = 319.73940190075456, tau = 4.15e-05, sigma = 2000.0, theta = 1.0
# Primal-dual method does not terminate after 24.14 seconds

# %%
# # Tuning parameteres for P-GRPDA
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
# from IPython.display import display

# # 1. Define your grids (adjust ranges as needed)
# beta_vals = np.logspace(4, 7, num=8)    # e.g. [1e4, 3e4, …, 1e8]
# tau_vals  = np.logspace(-5, -1, num=8)  # e.g. [1e-5, 3e-5, …, 1e-1]

# # 2. Run the nested grid‑search
# records = []
# for beta in beta_vals:
#     for tau in tau_vals:
#         values, x_star, y_star, tt = pd_Golden_Partial_adaptive(
#             J, prox_g_conj, K, x0, y0,
#             mu, mu1, gamma, beta,
#             phi, tau,
#             numb_iter=500
#         )
#         records.append({
#             'beta': beta,
#             'tau':  tau,
#             'J_final': values[-1]
#         })

# # 3. Build DataFrame and display
# df = pd.DataFrame(records)
# display(df.pivot(index='beta', columns='tau', values='J_final'))

# # 4. Plot a heatmap of J_final
# plt.figure(figsize=(6,5))
# pivot = df.pivot(index='beta', columns='tau', values='J_final')
# # we plot in log–log space
# im = plt.imshow(pivot,
#                 origin='lower',
#                 aspect='auto',
#                 extent=(np.log10(tau_vals[0]), np.log10(tau_vals[-1]),
#                         np.log10(beta_vals[0]), np.log10(beta_vals[-1])),
#                 cmap='viridis')
# plt.xlabel('log10(tau)')
# plt.ylabel('log10(beta)')
# plt.title('Final J over (beta, tau) grid')
# plt.colorbar(im, label='J_final')
# plt.show()

# # 5. Find best pair
# best = df.loc[df.J_final.idxmin()]
# print(f"→ Best β = {best.beta:.3e}, τ = {best.tau:.3e} → J_final = {best.J_final:.3e}")

# %%
# import numpy as np
# import pandas as pd

# # 1) recompute
# s_max = spla.svds(K, k=1, return_singular_vectors=False)[0]
# L     = s_max**2
# phi   = (1 + np.sqrt(5)) / 2

# # 2) choose a sigma‑grid
# sigma_vals = np.logspace(0, 4, num=10)   # e.g. [1,10,100,…,1000]

# records = []
# for sigma in sigma_vals:
#     # maximum allowed tau for this σ
#     tau_max_allowed = phi / (sigma + 2*L)
#     if tau_max_allowed <= 0:
#         # no feasible tau for this sigma
#         continue

#     # sample a few taus below that bound
#     tau_candidates = tau_max_allowed * np.array([0.2, 0.4,0.5, 0.9])
#     for tau in tau_candidates:
#         vals, x_star, y_star, tt, sigs, taus_hist = pd_Golden(
#             J, prox_g_conj, K, x0, y0,
#             sigma, tau, gamma, phi,
#             numb_iter=1000
#         )
#         J_final = vals[-1]
#         records.append((tau, sigma, J_final))

# # 3) assemble results
# df = pd.DataFrame(records, columns=['tau','sigma','J_final'])
# print(df)
# best = df.loc[df.J_final.idxmin()]
# print(f"→ Best tau={best.tau:.2e}, sigma={best.sigma:.2e}, J={best.J_final:.3e}")

# %%
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt

# # 1. Define candidate for grids (log‐scale is usually best)
# beta_vals = np.logspace(2, 6, num=10)   # e.g. [1e6, 1e6.75, …, 1e8]
# tau_vals  = np.logspace(-7, -3, num=5) # e.g. [1e-5, 3.16e-5, …, 1e-3]

# # 2. Prepare a list to collect results
# records = []

# # 3. Loop over all combinations
# for beta in beta_vals:
#     for tau in tau_vals:
#         out = pd_adaptive_Golden(
#             J, prox_g_conj, K, x0, y0,
#             tau, theta, beta, gamma,
#             tau_max, rho_val, phi,
#             numb_iter=2000   # one can take 1000 also to shorten the time consuming
#         )
#         values, x_star, y_star, times, sigmas, taus = out
#         J_final = values[-1]
#         records.append((beta, tau, J_final))

# # 4. Tabulate into a DataFrame
# df = pd.DataFrame(records, columns=['beta','tau','J_final'])
# print(df.pivot(index='beta', columns='tau', values='J_final'))

# # 5. Find the best combo
# best = df.loc[df.J_final.idxmin()]
# print(f"Best beta={best.beta:.3e}, tau={best.tau:.3e} → J={best.J_final:.3e}")

# # 6. (Optional) Heatmap visualization
# plt.figure(figsize=(6,5))
# # pivot to matrix
# mat = df.pivot(index='beta', columns='tau', values='J_final')
# im = plt.imshow(mat,
#                 origin='lower',
#                 aspect='auto',
#                 extent=(np.log10(tau_vals[0]), np.log10(tau_vals[-1]),
#                         np.log10(beta_vals[0]), np.log10(beta_vals[-1])))
# plt.colorbar(im, label='Final J')
# plt.xlabel('log10(tau)')
# plt.ylabel('log10(beta)')
# plt.title('Grid search over (beta, tau)')
# plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

#-----1) Set seaborn style-----
sns.set_style('darkgrid')
plt.rcParams['legend.facecolor'] = plt.rcParams['axes.facecolor']

#-----2) Define plot styles via rcParams-------
plt.rcParams.update({
    'font.size':        13,
    'figure.figsize':   (7, 5),
    'legend.fontsize':  16,
    'lines.linewidth':  2,
    'axes.labelsize':   16,
    'axes.titlesize':   10,
    'xtick.labelsize':  16,
    'ytick.labelsize':  16,
    'xtick.major.pad':  4,
    'ytick.major.pad':  4,
})

#--------3) Prepare data for plotting---------
values = [ans4[0], ans5[0], ans1[0], ans2[0]]
labels = ['aEGRPDA', 'P‑GRPDA', 'E‑GRPDA', 'Condat-Vu']
v_min = min(min(v) for v in values)
data = [np.array(v) - v_min for v in values]
iters = np.arange(len(data[0]))

#4) Define markers and size
markers = ['D', 'o', 's', '*']
msize = 7

#5) Plot
plt.figure()
for y, lbl, c, m in zip(data, labels, ['#008080','#8A2BE2','black', 'red'], markers):
    plt.plot(iters, y,
             color=c, marker=m, markersize=msize,
             markevery=max(1, len(iters)//10), label=lbl)

plt.yscale('log')
plt.xlabel('Iterations')
plt.ylabel(r'$F(x_n)-F^*$')
plt.legend(framealpha=1.0)

plt.grid(True)
plt.tight_layout()
# plt.savefig('log_scale_plot_comparison1.eps', dpi=600)
# files.download('log_scale_plot_comparison1.eps')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#1)--------Style------
sns.set_style('darkgrid')
plt.rcParams['legend.facecolor'] = plt.rcParams['axes.facecolor']
plt.rcParams.update({
    'font.size':        13,
    'figure.figsize':   (7, 5),
    'legend.fontsize':  16,
    'lines.linewidth':  2,
    'axes.labelsize':   16,
    'xtick.labelsize':  16,
    'ytick.labelsize':  16,
    'xtick.major.pad':  4,
    'ytick.major.pad':  4,
})

#2) Unpack results----------
_, _, _, _, sigma4, tau4 = ans4       # aEGRPDA
_, _, _, _, sigma1, tau1 = ans1       # E‑GRPDA
_, _, _, _, tau2, sigma2 = ans2       # Condat‑Vu

#3) Set max iterations
max_iter = 5000

#--------4) Plot tau_n on log‐scale
plt.figure()
for tau_vals, label, color, marker in [
    (tau4, 'aEGRPDA',       '#EE82EE', 'o'),
    (tau1, 'E‑GRPDA',       '#20B2AA', 's'),
    (tau2, 'Condat‑Vu','blue',    'D'),
]:
    tau_plot = np.array(tau_vals)[:max_iter]
    it = np.arange(len(tau_plot))
    me = max(1, len(it)//10)
    plt.plot(it, tau_plot,
             label=rf'{label}',
             color=color,
             marker=marker,
             markersize=7,
             markevery=me)

plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Primal Steps ($\tau_n$)')
plt.ylim([1e-8, 1e0])
plt.legend(framealpha=1.0, loc='lower right')
plt.tight_layout()
# plt.savefig('log_scale_plot_comparison1.eps', dpi=600)
# files.download('log_scale_plot_comparison1.eps')
plt.show()

#5) Plot
plt.figure()
for sigma_vals, label, color, marker in [
    (sigma4, 'aEGRPDA',       '#EE82EE', 'o'),
    (sigma1, 'E‑GRPDA',       '#20B2AA', 's'),
    (sigma2, 'Condat‑Vu', 'blue',   'D'),
]:
    sigma_plot = np.array(sigma_vals)[:max_iter]
    it = np.arange(len(sigma_plot))
    me = max(1, len(it)//10)
    plt.plot(it, sigma_plot,
             label=rf'{label}',
             color=color,
             marker=marker,
             markersize=7,
             markevery=me)

plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel(r'Dual Steps ($\sigma_n$)')
plt.ylim([1e-3, 1e5])
plt.legend(framealpha=1.0, loc='lower right')
plt.tight_layout()
plt.savefig('log_scale_plot_comparison1.eps', dpi=600)
files.download('log_scale_plot_comparison1.eps')
plt.show()
